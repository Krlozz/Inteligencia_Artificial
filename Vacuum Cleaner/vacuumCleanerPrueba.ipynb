# %%
goalState = {'A' : '0' , 'B' : '0' , 'C' : '0', 'D': '0'}
action = 0       # 0 = Clean , 1 = Dirty
cost = 0
roomStates = {'A' : '0' , 'B' : '0' , 'C' : '0', 'D': '0'}

print ("Room Inicial (A, B, C o D) = ")
location = input()
print()

for room in roomStates:
    action = input("Estado Room:" + room + " (Clean = 0, Dirty =1): ")
    roomStates[room] = action

print("\nEstado Actual: " + str(roomStates))
print("\nEstado Objetivo: " + str(goalState))

print("\n Vacuum Cleaner posicion " + location)

if (roomStates != goalState) :
    
    if (location == 'A'):
        if (roomStates['A'] == '1'): #Dirty
            roomStates['A'] = '0'
            cost+=1
            print("Room A was dirty\nLocation A has been cleaned\nCost for cleaning is 1.")
            
        if (roomStates == goalState):
            print("Goal state has been met.")
            print("\nPerformance Measurement: " + str(cost))
            
        else:
            print("\nA is clean")
            print("\nA -> B")
            print("\nCost for moving within rooms = 1")
            cost+=1
            
            if (roomStates['B'] == '1'):#If B is dirty
                roomStates['B'] = '0'
                cost+=1
                print("Location B was dirty\nLocation B has been cleaned\nCost for cleaning is 1.")
                
            if (roomStates == goalState):
                print("Goal state has been met.")
                print("\nPerformance Measurement: " + str(cost))
                
            else:
                print("\nA and B are clean but C is dirty")
                print("\nB -> C")
                print("\nCost for moving within rooms = 1")
                cost+=1
                
                roomStates['C'] = '0'
                cost+=1
                print("Location C was dirty\nLocation C has been cleaned\nCost for cleaning is 1.")
                
                if (roomStates == goalState):
                    print("Goal state has been met.")
                    print("\nPerformance Measurement: " + str(cost))
                
                else:
                    print("\nC is clean")
                    print("\nC -> D")
                    print("\nCost for moving within rooms = 1")
                    cost+=1
                    roomStates['D'] = '0'
                    
                    cost+=1
                    print("Location D was dirty\nLocation D has been cleaned\nCost for cleaning is 1.")
                    if (roomStates == goalState):
                        print("Goal state has been met.")
                        print("\nPerformance Measurement: " + str(cost))
    
    elif (location == "B"):
        if(roomStates['B'] == '1'):
            roomStates['B'] = '0'
            cost+=1
            print("Location B was dirty\nLocation B has been cleaned\nCost for cleaning is 1.")
            
        if (roomStates == goalState):
            print("Goal state has been met.")
            print("\nPerformance Measurement: " + str(cost))
            
        else:
            print("\nB is clean")
            print("\nB -> A")
            print("\nCost for moving within rooms = 1")
            cost+=1
            
            if(roomStates['A'] == '1'):
                roomStates['A'] = '0'
                cost+=1
                print("Location A was dirty\nLocation A has been cleaned\nCost for cleaning is 1.")
                
                if (roomStates == goalState):
                    print("Goal state has been met.")
                    print("\nPerformance Measurement: " + str(cost))
                
                else:
                    print("\nA is clean")
                    print("\nA -> B")
                    print("\nCost for moving within rooms = 1")
                    cost+=1

                    print("\nB is also clean")
                    print("\nB -> C")
                    print("\nCost for moving within rooms = 1")
                    cost+=1

                    roomStates['C'] = '0'
                    cost+=1
                    print("Location C was dirty\nLocation C has been cleaned\nCost for cleaning is 1.")
                    
                    print("\nC is also clean")
                    print("\nC -> D")
                    print("\nCost for moving within rooms = 1")
                    cost+=1

                    roomStates['D'] = '0'
                    cost+=1
                    print("Location D was dirty\nLocation D has been cleaned\nCost for cleaning is 1.")
                    
                    if (roomStates == goalState):
                        print("Goal state has been met.")
                        print("\nPerformance Measurement: " + str(cost))
            
            elif(roomStates['C'] == '1'):
                roomStates['C'] = '0'
                cost+=1
                print("Location C was dirty\nLocation C has been cleaned\nCost for cleaning is 1.")
                
                if (roomStates == goalState):
                    print("Goal state has been met.")
                    print("\nPerformance Measurement: " + str(cost))
                
                else:
                    print("\nC is clean")
                    print("\nC -> B")
                    print("\nCost for moving within rooms = 1")
                    cost+=1

                    print("\nB is also clean")
                    print("\nB -> A")
                    print("\nCost for moving within rooms = 1")
                    cost+=1

                    roomStates['A'] = '0'
                    cost+=1
                    print("Location A was dirty\nLocation A has been cleaned\nCost for cleaning is 1.")

                    if (roomStates == goalState):
                        print("Goal state has been met.")
                        print("\nPerformance Measurement: " + str(cost))
            else:
                if (roomStates['D'] == '1'):
                    roomStates['D'] = '0'
                    cost+=1
                    print("Location D was dirty\nLocation D has been cleaned\nCost for cleaning is 1.")

                    if (roomStates == goalState):
                        print("Goal state has been met.")
                        print("\nPerformance Measurement: " + str(cost))
    
    elif(location == 'C'):
        if (roomStates['C'] == '1'):
            roomStates['C'] = '0'
            cost+=1
            print("Location C was dirty\nLocation C has been cleaned\nCost for cleaning is 1.")
            
            print("\nC is also clean")
            print("\nC -> D")
            print("\nCost for moving within rooms = 1")
            cost+=1

            roomStates['D'] = '0'
            cost+=1
            print("Location D was dirty\nLocation D has been cleaned\nCost for cleaning is 1.")
            
        if (roomStates == goalState):
            print("Goal state has been met.")
            print("\nPerformance Measurement: " + str(cost))
        
        else:
            print("\nC is clean")
            print("\nC -> D")
            print("\nCost for moving within rooms = 1")
            cost+=1
            
            if (roomStates['D'] == '1'):
                roomStates['D'] = '0'
                cost+=1
                print("Location D was dirty\nLocation D has been cleaned\nCost for cleaning is 1.")
                if (roomStates == goalState):
                    print("Goal state has been met.")
                    print("\nPerformance Measurement: " + str(cost))
    
            print("\nD -> C")
            print("\nCost for moving within rooms = 1")
            cost+=1
            
            print("\nD and C are clean but A and B are dirty")
            print("\nB -> A")
            
            if (roomStates['B'] == '1'):
                roomStates['B'] = '0'
                cost+=1
                print("Location B was dirty\nLocation B has been cleaned\nCost for cleaning is 1.")
                
                if (roomStates == goalState):
                    print("Goal state has been met.")
                    print("\nPerformance Measurement: " + str(cost))
                
            
            else:
                print("\nB and C are clean but A is dirty")
                print("\nB -> A")
                print("\nCost for moving within rooms = 1")
                cost+=1
                
                roomStates['A'] = '0'
                cost+=1
                print("Location A was dirty\nLocation A has been cleaned\nCost for cleaning is 1.")
                
                if (roomStates == goalState):
                    print("Goal state has been met.")
                    print("\nPerformance Measurement: " + str(cost))
    
    elif(location == 'D'):
        if (roomStates['D'] == '1'):
            roomStates['D'] = '0'
            cost+=1
            print("Location D was dirty\nLocation D has been cleaned\nCost for cleaning is 1.")
            
        if (roomStates == goalState):
            print("Goal state has been met.")
            print("\nPerformance Measurement: " + str(cost))
        
        else:
            print("\nD is clean")
            print("\nD -> C")
            print("\nCost for moving within rooms = 1")
            cost+=1
            
            if (roomStates['C'] == '1'):
                roomStates['C'] = '0'
                cost+=1
                print("Location C was dirty\nLocation C has been cleaned\nCost for cleaning is 1.")
                
            if (roomStates == goalState):
                print("Goal state has been met.")
                print("\nPerformance Measurement: " + str(cost))
                
            else:
                print("\nD and C are clean but A and B are dirty")
                print("\nC -> B")
                print("\nCost for moving within rooms = 1")
                cost+=1
                
                roomStates['B'] = '0'
                cost+=1
                print("Location B was dirty\nLocation B has been cleaned\nCost for cleaning is 1.")
                print("\nB is clean")
                print("\nB -> A")
                print("\nCost for moving within rooms = 1")
                cost+=1
                if (roomStates['A'] == '1'):
                    roomStates['A'] = '0'
                    cost+=1
                    print("Location A was dirty\nLocation A has been cleaned\nCost for cleaning is 1.")
                
                    if (roomStates == goalState):
                        print("Goal state has been met.")
                        print("\nPerformance Measurement: " + str(cost))
        
    else:
        print("\nInvalid Start Location")
        
else:
    print("\nAll rooms are already clean")
    print("\nPerformance Measurement: " + str(cost))
# Out:
# Room Inicial (A, B, C o D) =
# D
#
# Estado Room:A (Clean = 0, Dirty =1): 1
# Estado Room:B (Clean = 0, Dirty =1): 1
# Estado Room:C (Clean = 0, Dirty =1): 0
# Estado Room:D (Clean = 0, Dirty =1): 0
#
# Estado Actual: {'A': '1', 'B': '1', 'C': '0', 'D': '0'}
#
# Estado Objetivo: {'A': '0', 'B': '0', 'C': '0', 'D': '0'}
#
#  Vacuum Cleaner posicion D
#
# D is clean
#
# D -> C
#
# Cost for moving within rooms = 1
#
# D and C are clean but A and B are dirty
#
# C -> B
#
# Cost for moving within rooms = 1
# Location B was dirty
# Location B has been cleaned
# Cost for cleaning is 1.
#
# B is clean
#
# B -> A
#
# Cost for moving within rooms = 1
# Location A was dirty
# Location A has been cleaned
# Cost for cleaning is 1.
# Goal state has been met.
#
# Performance Measurement: 5
